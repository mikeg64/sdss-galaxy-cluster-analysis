# %% [markdown]
# # Galatic Clusters

# %% [markdown]
# This Downloads an image and shows you it.

# %% [markdown]
# These are the imports that connect to the libarys

# %%
# Python standard-library
from urllib.parse import urlencode
from urllib.request import urlretrieve


import pandas as pd
import numpy as np
import matplotlib

# Third-party dependencies
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.table import Table

from IPython.display import Image

# Set up matplotlib and use a nicer set of plot parameters
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# This Finds information about the Leo Triplet cluster you can find a different cluster by replacing every thing that says Leo Triplet with the galaxy cluster you want.But remember to makesure its on sky coord(A database of the universe),you can check this with Sesame http://cds.u-strasbg.fr/cgi-bin/Sesame

# %%
# initialize a SkyCoord object named hcg7_center at the location of HCG 7
gc_center = SkyCoord.from_name('Leo Triplet')
print(gc_center.ra, gc_center.dec)
print(gc_center.ra.hour, gc_center.dec)
# Out:
# 169d45m00s 13d12m00s
# 11.316666666666668 13d12m00s

# %%
This tells sky coord how big you want the image and downloads it to your disk.

# %%
im_size = 105*u.arcmin #I recommend not going under 80 arc minutes
im_pixels = 1024 
cutoutbaseurl = 'http://skyservice.pha.jhu.edu/DR12/ImgCutout/getjpeg.aspx'
query_string = urlencode(dict(ra=gc_center.ra.deg, 
                              dec=gc_center.dec.deg, 
                              width=im_pixels, height=im_pixels, 
                              scale=im_size.to(u.arcsec).value/im_pixels))
url = cutoutbaseurl + '?' + query_string

urlretrieve(url, 'gc_SDSS_cutout.jpg')
# Out:
# ('gc_SDSS_cutout.jpg', <http.client.HTTPMessage at 0x26c1bf69ef0>)

# %%
Image('gc_SDSS_cutout.jpg')

# %% [markdown]
# # This downloads 8 galaxy cluster images to your computer

# %% [markdown]
# If you haven't already done these imports  remember to do them so your notebook can connect to the libarys.If you start a new notebook or restart the current you also have to do them.

# %%
# Python standard-library
from urllib.parse import urlencode
from urllib.request import urlretrieve


import pandas as pd
import numpy as np
import matplotlib

# Third-party dependencies
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.table import Table
from astropy.io import ascii

from IPython.display import Image

# Set up matplotlib and use a nicer set of plot parameters
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# This is a list of 8 gallaxy clusters.

# %%
clusters=[['Abell 1656',105],['Copeland Septet',105],['NGC 7331',105],['Leo Triplet',105],['NGC 4477',105], ['NGC 6027 ',105], ['HCG 92',105],['Virgo Cluster',105]]

# %%
print(clusters[1][0])
# Out:
# Copeland Septet
